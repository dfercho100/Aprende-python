# %% [markdown]
# # Este es el segundo workshop

# %% [markdown]
# //Calculadora de reservas de entradas de cine.

# %% [markdown]
# * crea una variable llamada precio_base y asignale un valor 15,
# * crea otro variable edad y asignale 21,
# * crea una variable tpo_asiento y asignale un texto Gold,
# * crea una variable hora_show y asignale el texto Noche

# %%
precio_base = 15
edad = 21
tipo_asiento = "Gold"
hora_show = "Noche"

# %% [markdown]
# Si la edad es mayor que 17 entonces imprime "17, asi que el usuario puede reservar un billete", si el usuario es mayor o igual que 21 imprime "21, asi que el usuario es apto para ver los programas nocturnos"; Despues crea las variables es_miembro y es_FinDeSemna y asignales un valor de tipo booleano a cada uno en donde es_miembro es verddero y es_FiDeSemana es falso

# %%
if edad > 17:
    print("17, asi que el usuario puede reservar un billete")
if edad >= 21:
    print("21, asi que el usuario es apto para ver los programas nocturnos")

es_miembro = True
es_FinDeSemna = False
# Out:
# 17, asi que el usuario puede reservar un billete
# 21, asi que el usuario es apto para ver los programas nocturnos

# %% [markdown]
# crea una variable llamada descuento y asignale el valor 0, si es_miembro tiene un descuento de 3 imprime "el descuento es 3, el usuario califica para tener un descuento de membresia" de lo contrario imprime "si no hay descuento el usuario no califica para tener un descuento de membresia"; luego imprime descuento junto con el descuentoo actualizado(que es 3)

# %%
descuento = 0
if es_miembro:
    descuento = 3
    print("el descuento es 3, el usuario califica para tener un descuento de membresia")
else:
    print("si no hay descuento el usuario no califica para tener un descuento de membresia")
print("descuento:", descuento)
# Out:
# el descuento es 3, el usuario califica para tener un descuento de membresia
# descuento: 3

# %% [markdown]
# El descuento de membresia debe aplicarse solo a los miembros que son mayores o iguales a 21

# %%
# El descuento de membresía debe aplicarse solo a los miembros que son mayores o iguales a 21
descuento = 0
if es_miembro and edad >= 21:
    descuento = 3
    print("el descuento es 3, el usuario califica para tener un descuento de membresia")
else:
    print("si no hay descuento el usuario no califica para tener un descuento de membresia")
print("descuento:", descuento)
# Out:
# el descuento es 3, el usuario califica para tener un descuento de membresia
# descuento: 3

# %% [markdown]
# cambie el valor de es_miembro a False (como si l usario no fuera miembro). en la terminal se vera descuento:0

# %%
es_miembro = False
print("descuento:", descuento)
# Out:
# descuento: 0

# %% [markdown]
# Mira como aparece ahora:

# %%
descuento = 0
if es_miembro and edad >= 21:
    descuento = 3
    print("el descuento es 3, el usuario califica para tener un descuento de membresia")
else:
    print("si no hay descuento el usuario no califica para tener un descuento de membresia")
print("descuento:", descuento)
# Out:
# si no hay descuento el usuario no califica para tener un descuento de membresia
# descuento: 0

# %% [markdown]
# crea la variable cargos_extra y asignale valor 0, verifica si es_FinDeSemna es veraz, dentro del cuerpo de if actualiza cargos_extra con el valor 2 e imprime "cargos extra son 2, asi que se aplicarán" de lo contrario imprime "cargos extra son 0 asi que no se aplicarán". Debajo imprime cargos_extra seguido de su valor actualizado

# %%
cargos_extra = 0
if es_FinDeSemna:
    cargos_extra = 2
    print("cargos extra son 2, asi que se aplicarán")
else:
    print("cargos extra son 0 asi que no se aplicarán")
print("cargos_extra:", cargos_extra)
# Out:
# cargos extra son 0 asi que no se aplicarán
# cargos_extra: 0

# %% [markdown]
# los cargos extra deberian aplicarse si el show es de noche, la condicion deberia ser: si es fin de semana o si el show es de noche

# %%
# Los cargos extra deberían aplicarse si es fin de semana o si el show es de noche
cargos_extra = 0
if es_FinDeSemna or hora_show == "Noche":
    cargos_extra = 2
    print("cargos extra son 2, asi que se aplicarán")
else:
    print("cargos extra son 0 asi que no se aplicarán")
print("cargos_extra:", cargos_extra)
# Out:
# cargos extra son 0 asi que no se aplicarán
# cargos_extra: 0

# %% [markdown]
# actualizamos de nuevo cargos extra a 2 para que muestre por pantalla

# %%
cargos_extra = 2
print("cargos_extra:", cargos_extra)
# Out:
# cargos_extra: 2

# %% [markdown]
# si la edad es mayor o igual a 21 imprime "la edad es mayor o es igual a 21, asi que la reserva de boletos esta cumplida" de lo contrario imprime "la edad no es mayor ni igual a 21, asi que la reserva  de boletos falló debido a restricciones"

# %%
if edad >= 21:
    print("la edad es mayor o es igual a 21, asi que la reserva de boletos esta cumplida")
else:
    print("la edad no es mayor ni igual a 21, asi que la reserva  de boletos falló debido a restricciones")
# Out:
# la edad es mayor o es igual a 21, asi que la reserva de boletos esta cumplida
