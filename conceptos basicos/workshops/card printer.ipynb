# %% [markdown]
# # Este es el primer workshop

# %% [markdown]
# Cree una variable llamada name y asignele el string greeting e imprima el valor de la varible con la funcion print().Debera ver el nombre impreso en la terminal pero queremos ver que tipo de dato imprime (para eso llama la funcion type()). El reporte deberá mostrar si el estudiante esta actualmente matriculado o no; para verlo por pantalla declare una variable llamada is_student y asignele un valor booleano. Imprima ambas variables is_student y type() en la misma funcion print().
#
# El reporte deebrá tener mas informacion del estudiante como la edad, asi que declare una variable llamada age y asignele el valor entero 20 imprima la edad del estudiante junto con el tipo de dato de la variable age. Por ultimo declare una variable llamada score y asignele el valor 80.5 e imprima su resultado utilizando la funcion isinstance() para comprobar que la puntacion es un decimal e imprima score con el tipo de dato.

# %%
# Create variable name with string value
name = "greeting"
print(name, type(name))

# Create variable is_student with boolean value
is_student = True
print(is_student, type(is_student))

# Create variable age with integer value
age = 20
print(age, type(age))

# Create variable score with float value
score = 80.5
print(isinstance(score, int), isinstance(score, float))
print(score, type(score))
# Out:
# greeting <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# False True
# 80.5 <class 'float'>
