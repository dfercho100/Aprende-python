# %% [markdown]
# # Condicionales

# %% [markdown]
# Los condicioneles y los numeros numeros booleanos dan como resultado true o false, los condicionales son: mayor que menor que igual mayor e igual que menor e igual que y no es igual:

# %%
print(3 > 4) # False
print(3 < 4) # True
print(3 == 4) # False
print(4 == 4) # True
print(3 != 4) # True
print(3 >= 4) # False
print(3 <= 4) # True
# Out:
# False
# True
# False
# True
# True
# False
# True

# %% [markdown]
# # Bucle if else y condicional elif

# %% [markdown]
# Podemos agregar un bocle if de la siguiente manera:

# %%
age = 18

if age >= 18:
    print('You are an adult')
# Out:
# You are an adult

# %% [markdown]
# Es como decir si quieres esto, imprimelo

# %% [markdown]
# Tambien existe else en phyton que es como decir "si no quiere estos, entonces toma esto":

# %%
age = 12

if age >= 18:
    print('You are an adult')
else:
    print('You are not an adult yet')
# Out:
# You are not an adult yet

# %% [markdown]
# Pero paython añade mas opciones a la conndicional if else, que es elif, que como decir "te doy variable, si es verdad lo que indica en la primera condicion imprimela, pero si la segunda condicion es verdadera y la primera es falsa imprime la segunda.... y si ninguna de las dos es verdadera imprime la tercera opcion":

# %%
age = 12

if age >= 18:
    print('You are an adult')
elif age <= 13:
    print('You are a teenager')
else:
    print('You are a child')
# Out:
# You are a teenager

# %% [markdown]
# se pueden agregar tantos elif como desee:

# %%
age = 2

if age >= 65:
    print('You are a senior citizen')
elif age >= 30:
    print('You are an adult in your prime')
elif age >= 18:
    print('You are a young adult')
elif age >= 13:
    print('You are a teenager')
elif age >= 3:
    print('You are a young child')
else:
    print('You are a toddler or an infant')
# Out:
# You are a toddler or an infant

# %% [markdown]
# # Condicional anidado

# %% [markdown]
# Hay situaciones en los que te enfrentarás en  situaciones en la se tienen que comparar varios valores a la vez y aqui es donde entran las condicionales anidadas:

# %%
is_citizen = True
age = 25

if is_citizen:
    if age >= 18:
        print('You are eligible to vote') # You are eligible to vote
else:
    print('You are not eligible to vote')
# Out:
# You are eligible to vote

# %% [markdown]
# En Python, un if anidado es simplemente una estructura de control condicional donde se coloca un if dentro de otro if. Esto permite realizar verificaciones más complejas.

# %%
x = 10
y = 5

if x > y:
    print("x es mayor que y")
    if x > 8:
        print("x es también mayor que 8")
    else:
        print("x es menor o igual a 8")
else:
    print("x no es mayor que y")
# Out:
# x es mayor que y
# x es también mayor que 8

# %% [markdown]
# En este caso:
#
# * Primero se verifica si x es mayor que y.
# * Si lo es, se ejecuta un segundo if que evalúa si x es mayor que 8. Si no es mayor que 8, se entra en el bloque else.

# %% [markdown]
# # Operadores booleanos

# %% [markdown]
# Hay 3 opeardores booleanos and or not y cada uno tiejne funciones muy diferentes cuando se emplean
#
# El operador and toma dos operandos y devuelve el primer operando si es falso; de lo contrario devuelve el segundo operando, ambos operandos deben  ser verdaderos para que una expresion dé como resultado un valor verdadero

# %%
print(is_citizen and age)
# da como resultado: 25 porque ambos valores son verdaderos
# Out:
# 25

# %% [markdown]
# en phython algunos valores se consideran truthy y falsy. Los valores truthy se consideran como verdaderos y los valores falsy se consideran como falsos. para comprobar si un valor es truthy o falsy se puede usar la funcion bool():

# %%
print(bool(False)) # False
print(bool(0))  # False
print(bool('')) # False

print(bool(True)) # True
print(bool(1)) # True
print(bool('Hello')) # True
# Out:
# False
# False
# False
# True
# True
# True

# %% [markdown]
# # Laboratorio planeador de viaje
#
# Para este laboratorio, utilizarás declaraciones condicionales para determinar si es posible desplazarse (commuting) según el clima, la distancia a viajar y la disponibilidad de un vehículo.
#
# **Objetivo:** Cumplir con las historias de usuario a continuación y lograr que todas las pruebas pasen para completar el laboratorio.
#
# Debes crear las siguientes variables:
#
# * **distance_mi** (un número que representa la distancia a viajar en millas)
# * **is_raining** (un valor booleano que indica si el usuario está experimentando clima lluvioso)
# * **has_bike** (un valor booleano que indica si el usuario tiene una bicicleta)
# * **has_car** (un valor booleano que indica si el usuario tiene un automóvil)
# * **has_ride_share_app** (un valor booleano que indica si el usuario tiene una aplicación que le permite solicitar un viaje)
#
# Debes usar declaraciones condicionales para determinar si es posible desplazarse según los valores de estas variables.
#
# Debes usar sentencias **if, elif y else** para evaluar las categorías de distancia en orden ascendente.
#
# * Si **distance_mi** tiene un valor *falsy* (es decir, 0, None, "", etc.):
#   Debes imprimir **False**.
#
# * Si la distancia es **menor o igual a 1 milla**:
#   Debes imprimir **True** solo si **no está lloviendo**.
#   De lo contrario, debes imprimir **False**.
#
# * Si la distancia es **mayor que 1 milla y menor o igual a 6 millas**:
#   Debes imprimir **True** solo si la persona **tiene una bicicleta** y **no está lloviendo**.
#   De lo contrario, debes imprimir **False**.
#
# * Si la distancia es **mayor que 6 millas**:
#   Debes imprimir **True** si la persona **tiene un auto** o **tiene una aplicación de viaje compartido (ride-share)**.
#   De lo contrario, debes imprimir **False**.
#
# ---

# %%
distance_mi= 5
is_raining= True  
has_bike= True
has_car= False 
has_ride_share_app = True 
if not distance_mi:
    print(False)
elif distance_mi <= 1:
        if not is_raining:
            print(True) 
        else:
            print(False)
elif distance_mi <= 6:
    if has_bike and not is_raining:
        print(True)
    else:
        print(False)
else:
    if has_car or has_ride_share_app:
        print(True)
    else:
        print(False)
# Out:
# False
