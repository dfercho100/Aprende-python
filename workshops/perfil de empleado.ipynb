# %% [markdown]
# # Este es el cuarto workshop

# %% [markdown]
# * Crea la variable primer_nombre con el string John
# * Cera la variable segundo_nombre con elm string Doe
# * imprime las variables en pantalla

# %%
primer_nombre = "John"
segundo_nombre = "Doe"
print(primer_nombre, segundo_nombre)
# Out:
# John Doe

# %% [markdown]
# Para concatenar se puede usar tambien el operador +.
# * Crea la variable nombre_completo para concatenarlo con primer_nombre y segundo_nombre, despues imrime la variable nombre_completo

# %%
nombre_completo = primer_nombre + " " + segundo_nombre # para no aparecer pegados se agrega un espacio entre comillas
print(nombre_completo)
# Out:
# John Doe

# %% [markdown]
# * crea la variable direccion para almacenar la direccion del empleado asignandole '123 calle principal' y finalmente imprimelo

# %%
direccion = '123 calle principal'
print(direccion)
# Out:
# 123 calle principal

# %% [markdown]
# Para que no se vea la direccion incompleta, aniade el añade el numero de departamento donde vive; cuando quieres añadir contenido al final de una cadena de texto puedes usar el operador += (o asignacion aumentada), recuerda que los strings son inmutables por lo tanto esta operacion no cambia el string original, en lugar de eso crea una cadena y la reasigna a la variable.
# * con ayuda del operador += añade la cadena ', apartamento 4B' para la variable direccion

# %%
direccion += ', apartamento 4B'
print(direccion)
# Out:
# 123 calle principal, apartamento 4B

# %% [markdown]
# * Crea la variable edad_del_empleado asisgnadole el valor 28
# * Crea la variable info_del_empleado y asignale el resultado de la concatenacion (nombre_completo y una cadena 'tiene seguido de un  espacio')

# %%
edad_del_empleado = 28
info_del_empleado = nombre_completo + ' tiene '  # "tiene" seguido de un espacio

print(edad_del_empleado)
print(info_del_empleado)
# Out:
# 28
# John Doe tiene

# %% [markdown]
# * Concatena la edad del empleado al final de la variable info_del_empleado, ten cuidado de que no se genere un TypeError

# %%
info_del_empleado += str(edad_del_empleado)
print(info_del_empleado)
# Out:
# John Doe tiene 28

# %% [markdown]
# * Completa la frase concatenando la cadena de texto ' años' con un espacio al comienzo y vuelve a imprimir la variable info_del_empleado

# %%
info_del_empleado += ' años'
print(info_del_empleado)
# Out:
# John Doe tiene 28 años

# %% [markdown]
# * Crea la variable años_de_experiencia y asignale el entero 5
# * Crea la variable info_de_experiencia, asignale la cadena 'experiencia: ' concatenando la variable años_experiencias y 'años'
# * imprime la informacion

# %%
años_de_experiencia = 5
info_de_experiencia = 'experiencia: ' + str(años_de_experiencia) + ' años'
print(info_de_experiencia)
# Out:
# experiencia: 5 años

# %% [markdown]
# Concatenando muchos strings con + y convertir otros a numero usando str() puede ser un trabajo tedioso, es por eso a que a partir de python 3.6 introdujo los f strings para resolver esto. Tan solo con poner una f y poner  las variables y expresiones dentro de llaves se concatenan.
# * Crea la variable tarjeta_empleado y asignale f string para que se pueda ver empleado: y el valor de la variable info_del_empleado

# %%
tarjeta_empleado = f"empleado: {info_del_empleado}"
print(tarjeta_empleado)
# Out:
# empleado: John Doe tiene 28 años

# %% [markdown]
# Debemos añadirle mas informacion a tarjeta_empleado como el nombre de empleado y la edad del empleado

# %%
# añadimos nombre y edad a la tarjeta existente
tarjeta_empleado += f", nombre: {nombre_completo}, edad: {edad_del_empleado}" # se separan con comas para que no se vea pegado o con | si se prefiere
print(tarjeta_empleado)
# Out:
# empleado: John Doe tiene 28 años, nombre: John Doe, edad: 28

# %% [markdown]
# Añadiendo los detalles finales a la tarjeta:
# * Crea una variable llamada posicion y asignale la cadena 'Data Analyst'
# * crea la variable salario y asignale el valor $2.198.310
# * Actualiza la trajeta del  empleado incluyendole la posicion y el salario
# * Imprime tarjeta_empleado para ver el resultado

# %%
posicion = 'Data Analyst'
salario = "$2,198,310"

tarjeta_empleado += f", posicion: {posicion}, salario: {salario}"
print(tarjeta_empleado)
# Out:
# empleado: John Doe tiene 28 años, nombre: John Doe, edad: 28, posicion: Data Analyst, salario: $2,198,310

# %%
# reconstruimos la tarjeta usando saltos de línea para que no salga
# todo en una sola línea
tarjeta_empleado = (
    f"empleado: {info_del_empleado}\n"
    f"nombre: {nombre_completo}\n"
    f"edad: {edad_del_empleado}\n"
    f"posicion: {posicion}\n"
    f"salario: {salario}"
)
print(tarjeta_empleado)
# Out:
# empleado: John Doe tiene 28 años
# nombre: John Doe
# edad: 28
# posicion: Data Analyst
# salario: $2,198,310

# %% [markdown]
# Al trabajar con cadenas de texto pueden ser utiles los slicing cuya sintaxis es string[start:stop]:
# * Define codigo_empleado y asignale 'DEV-2026-JD-001'
# * Crea la variable departamento y asignale el corte de codigo_empleado en donde el index sea 0 hasta 3
# * Imprime departamento

# %%
codigo_empleado = 'DEV-2026-JD-001'
departamento = codigo_empleado[0:3]  # índices 0 hasta 3 (excluye 3)
print(departamento)
# Out:
# DEV

# %% [markdown]
# * Crea la variable año_codigo y asignele el corte de codigo_empleado en donde el index sea 4 hasta 8
# * Crea la variable Iniciales y asignale el corte de codigo_empleado en donde el index sea 9 hasta 11
# * Imprime las dos variables

# %%
año_codigo = codigo_empleado[4:8]
Iniciales = codigo_empleado[9:11]

print(año_codigo)
print(Iniciales)
# Out:
# 2026
# JD

# %% [markdown]
# * Crea la variable ultimos_tres y usa el index negativo para extraer los ultimos trwe caracteres de codigo_empleado
# * Imprime la variable ultimos_tres

# %%
ultimos_tres = codigo_empleado[-3:]  # últimos tres caracteres usando índice negativo
print(ultimos_tres)
# Out:
# 001

# %% [markdown]
# # Finalmente te muestro el codigo completo 🎉📊

# %%
primer_nombre = "John"
segundo_nombre = "Doe"

nombre_completo = primer_nombre + " " + segundo_nombre

direccion = '123 calle principal'
direccion += ', apartamento 4B'

edad_del_empleado = 28
info_del_empleado = nombre_completo + ' tiene '
info_del_empleado += str(edad_del_empleado)
info_del_empleado += ' años'

años_de_experiencia = 5
info_de_experiencia = f'experiencia: {años_de_experiencia} años'

tarjeta_empleado = (
    f"empleado: {info_del_empleado}\n"
    f"nombre: {nombre_completo}\n"
    f"edad: {edad_del_empleado}\n"
    f"posicion: {posicion}\n"
    f"salario: {salario}"
)

codigo_empleado = 'DEV-2026-JD-001'
departamento = codigo_empleado[0:3]
año_codigo = codigo_empleado[4:8]
Iniciales = codigo_empleado[9:11]
ultimos_tres = codigo_empleado[-3:]

# impresiones finales
print(tarjeta_empleado)
print(departamento, año_codigo, Iniciales, ultimos_tres)
# Out:
# empleado: John Doe tiene 28 años
# nombre: John Doe
# edad: 28
# posicion: Data Analyst
# salario: $2,198,310
# DEV 2026 JD 001
